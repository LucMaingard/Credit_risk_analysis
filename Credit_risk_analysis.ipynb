# %%
import numpy as np
import pandas as pd

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

data = pd.read_csv('german_credit.csv')
data.head()
# Out:
#    Creditability  Account Balance  Duration of Credit (month)  \
# 0              1                1                          18
# 1              1                1                           9
# 2              1                2                          12
# 3              1                1                          12
# 4              1                1                          12
#
#    Payment Status of Previous Credit  Purpose  Credit Amount  \
# 0                                  4        2           1049
# 1                                  4        0           2799
# 2                                  2        9            841
# 3                                  4        0           2122
# 4                                  4        0           2171
#
#    Value Savings/Stocks  Length of current employment  Instalment per cent  \
# 0                     1                             2                    4
# ...

# %%
#check all columns
data.dtypes
# Out:
# Creditability                        int64
# Account Balance                      int64
# Duration of Credit (month)           int64
# Payment Status of Previous Credit    int64
# Purpose                              int64
# Credit Amount                        int64
# Value Savings/Stocks                 int64
# Length of current employment         int64
# Instalment per cent                  int64
# Sex & Marital Status                 int64
# Guarantors                           int64
# Duration in Current address          int64
# Most valuable available asset        int64
# Age (years)                          int64
# Concurrent Credits                   int64
# Type of apartment                    int64
# No of Credits at this Bank           int64
# Occupation                           int64
# No of dependents                     int64
# Telephone                            int64
# Foreign Worker                       int64
# dtype: object

# %%
#find missing values
missing = data.isnull().sum()
missing
# Out:
# Creditability                        0
# Account Balance                      0
# Duration of Credit (month)           0
# Payment Status of Previous Credit    0
# Purpose                              0
# Credit Amount                        0
# Value Savings/Stocks                 0
# Length of current employment         0
# Instalment per cent                  0
# Sex & Marital Status                 0
# Guarantors                           0
# Duration in Current address          0
# Most valuable available asset        0
# Age (years)                          0
# Concurrent Credits                   0
# Type of apartment                    0
# No of Credits at this Bank           0
# Occupation                           0
# No of dependents                     0
# Telephone                            0
# Foreign Worker                       0
# dtype: int64

# %%
#check unique values in columns with missing
data['Creditability'].unique()
# Out:
# array([1, 0])

# %%
#define test and get val data
feature_cols = data.columns.drop('Creditability')
y = data['Creditability']

# train test data
train_full = pd.read_csv('Training50.csv')
test_full = pd.read_csv('Test50.csv')

#validate data
drop_cols = ['Creditability', 'Unnamed: 0']
val_X = train_full.drop(drop_cols, axis=1)
test_X = test_full.drop(drop_cols, axis=1)
val_y = train_full['Creditability']
test_y = test_full['Creditability']

#train data
train_X = data[feature_cols]
train_y = y

# %%
val_X.head()
# Out:
#    Account.Balance  Duration.of.Credit..month.  \
# 0                3                           6
# 1                1                          15
# 2                1                          42
# 3                3                          36
# 4                3                          24
#
#    Payment.Status.of.Previous.Credit  Purpose  Credit.Amount  \
# 0                                  2        3           2108
# 1                                  1        4            950
# 2                                  2        3           7174
# 3                                  3        4           7980
# 4                                  3        2           2028
#
#    Value.Savings.Stocks  Length.of.current.employment  Instalment.per.cent  \
# 0                     1                             3                    2
# 1                     1                             4                    4
# 2                     4                             3                    4
# ...

# %%
#Define and fit model
model = RandomForestRegressor(n_estimators=100, random_state=0)
model.fit(train_X, train_y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
#predict
preds = model.predict(val_X)

# %%
#score
from sklearn.metrics import mean_absolute_error

scores = mean_absolute_error(val_y, preds)
print('MAE Score: ', scores)
# Out:
# MAE Score:  0.28815999999999997
